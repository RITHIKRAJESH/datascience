# %%
s='hello'

# %%
u="hello"

# %%
print(s)
# Out:
# hello

# %%
print(u)
# Out:
# hello

# %%
s1="python"

# %%
s2="world"

# %%
s3=s1+' '+s2

# %%
print(s3)
# Out:
# python world

# %%
print(len(s3))
# Out:
# 12

# %%
print(s3.upper())
# Out:
# PYTHON WORLD

# %%
print(s3.capitalize())
# Out:
# Python world

# %%
print(s3.lower())
# Out:
# python world

# %%
print('hello world how are you'.split(' '))
# Out:
# ['hello', 'world', 'how', 'are', 'you']

# %%
print('boo'.replace('o','e'))
# Out:
# bee

# %%
word='Jewellery'

# %%
print(word.find('well'))
# Out:
# 2

# %%
print(word.find('is'))
# Out:
# -1

# %%
s3='%s%s%d' % (s1,s2,1011)

# %%
print(s3)
# Out:
# pythonworld1011

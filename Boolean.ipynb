# %%
T=True

# %%
F=False

# %%
print (T,F)
# Out:
# True False

# %%
p=5>3

# %%
print (p)
# Out:
# True

# %%
q=-1<-12.5

# %%
print (q)
# Out:
# False

# %%
print (p and q)
# Out:
# False

# %%
print (p or q)
# Out:
# True

# %%
print (not q)
# Out:
# True

# %%
a=7

# %%
b=3

# %%
sum=a+b

# %%
print (sum)
# Out:
# 10

# %%
dif=a-b

# %%
print (dif)
# Out:
# 4

# %%
pro=a*b

# %%
print (pro)
# Out:
# 21

# %%
quo=a/b

# %%
print (quo)
# Out:
# 2.3333333333333335

# %%
iquo=a//b

# %%
print (iquo)
# Out:
# 2

# %%
rem=a%b

# %%
print (rem)
# Out:
# 1

# %%
pow=a**b

# %%
print (pow)
# Out:
# 343

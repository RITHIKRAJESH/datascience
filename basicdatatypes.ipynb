# %%
a=5

# %%
print (a)
# Out:
# 5

# %%
print (type(a))
# Out:
# <class 'int'>

# %%
f=1.5

# %%
print (f)
# Out:
# 1.5

# %%
print (type(f))
# Out:
# <class 'float'>

# %%
s="hello"

# %%
print (s)
# Out:
# hello

# %%
print (type(s))
# Out:
# <class 'str'>

# %%
b=True

# %%
print (b)
# Out:
# True

# %%
print (type(b))
# Out:
# <class 'bool'>
